# %% [markdown]
# <a href="https://colab.research.google.com/github/luida-M/Generaci-n-de-moldes-de-Ropa-Personalizada-con-IA/blob/main/Trabajo_Final%2BLuida_Medina.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **prepara el entorno de Colab montando el Google Drive, te autentica con Google, configura Git con tu información, clona un repositorio de GitHub y luego intenta cambiar el directorio de trabajo.**

# %%
import os # Importa el módulo os

# Montar Google Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# Importar bibliotecas necesarias para autenticación con Google
from google.colab import auth # Importa el módulo 'auth' de 'google.colab' para la autenticación
import gspread  # Importa 'gspread' para interactuar con Google Sheets
from google.auth import default # Importa la función 'default' para obtener credenciales

# Autenticación con Google
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# Configuración de Git
# !git config --global user.email "luidamedina@gmail.com"
# !git config --global user.name "Luida Medina"

#Clonar el repositorio (corregido)
# !git clone https://github.com/luida-M/Generaci-n-de-moldes-de-Ropa-Personalizada-con-IA.git

# Clona el repositorio usando SSH
# !git clone git@github.com:luida-M/Generaci-n-de-moldes-de-Ropa-Personalizada-con-IA.git
# Cambiar al directorio del repositorio
# %cd Generaci-n-de-moldes-de-Ropa-Personalizada-con-IA
# %cd /content/drive/MyDrive/Trabajo_Final+Luida_Medina.ipynb
# Out:
# Mounted at /content/drive
# Cloning into 'Generaci-n-de-moldes-de-Ropa-Personalizada-con-IA'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 31 (delta 5), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (31/31), 21.20 KiB | 7.06 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# fatal: destination path 'Generaci-n-de-moldes-de-Ropa-Personalizada-con-IA' already exists and is not an empty directory.
# /content/Generaci-n-de-moldes-de-Ropa-Personalizada-con-IA
# [Errno 20] Not a directory: '/content/drive/MyDrive/Trabajo_Final+Luida_Medina.ipynb'
# /content/Generaci-n-de-moldes-de-Ropa-Personalizada-con-IA

# %% [markdown]
# **Instala e importa las bibliotecas y módulos correspondientes. Configura el OpenAI:**

# %%
# !pip install openai==0.28
# !pip install pillow
# !pip install google.colab

import openai
import google.colab
from io import BytesIO
from PIL import Image
import requests

# Configurar API Key desde variable de entorno
openai.api_key = "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"

# %% [markdown]
# **Distintas forma de generar los moldes:**

# %% [markdown]
# **1. Genera la imagen con DALL·E o NightCafe:**

# %%
def calcular_medidas(tipo_prenda, talla):
    medidas = {
        'camisa': {
            'S': {'pecho': 90, 'cintura': 80, 'largo': 65, 'manga': 60},
            'M': {'pecho': 96, 'cintura': 86, 'largo': 68, 'manga': 62},
            'L': {'pecho': 102, 'cintura': 92, 'largo': 71, 'manga': 64},
            'XL': {'pecho': 108, 'cintura': 98, 'largo': 74, 'manga': 66},
        }
    }
    return medidas[tipo_prenda].get(talla, "Talla no disponible")

def generar_imagen_openai(prompt, nombre_archivo="imagen_generada.png"):
    try:
        print(f"Generando imagen con el siguiente prompt:\n{prompt}")

        response = openai.Image.create(
            prompt=prompt,
            n=1,
            size="1024x1024"
        )

        if 'data' in response and len(response['data']) > 0:
            image_url = response['data'][0]['url']
            print("URL de la imagen generada:", image_url)

            response_img = requests.get(image_url)
            img = Image.open(BytesIO(response_img.content))
            img.show()

            path_guardado = f"/content/drive/My Drive/{nombre_archivo}"
            img.save(path_guardado)
            print(f"Imagen guardada en {path_guardado}")
            return image_url, path_guardado

        else:
            print("Error: No se recibió ninguna imagen en la respuesta.")
            return None, None

    except Exception as e:
        print("Ocurrió un error:", str(e))
        return None, None

def generar_prompt_nightcafe(tipo_prenda, talla, descripcion=""):
    prompt = f"Imagen de una {tipo_prenda}, talla {talla}. {descripcion} Dibujo de alta calidad, estilo vector, con detalles técnicos."
    print("\n🔹 Copia este prompt y pégalo en NightCafe para generar la imagen:")
    print(prompt)
    return prompt

def generar_imagen_completa(tipo_prenda, talla, herramienta):
    prompt = f"Imagen completa de una {tipo_prenda}, talla {talla}. El diseño debe mostrar la prenda en su totalidad con detalles claros. Dibujo de alta calidad, monocromo, estilo vector."
    if herramienta == "1":
        return generar_imagen_openai(prompt, nombre_archivo=f"completa_{tipo_prenda}_{talla}.png")
    elif herramienta == "2":
        return generar_prompt_nightcafe(tipo_prenda, talla, "Diseño completo de la prenda")

def ingresar_y_generar_patron():
    print("Elige el tipo de prenda:")
    print("1. Camisa")
    tipo_prenda = input("Ingresa el número del tipo de prenda (1): ")
    tipo_prenda = 'camisa' if tipo_prenda == '1' else None
    if not tipo_prenda:
        print("Opción no válida.")
        return

    talla = input("Ingresa la talla (S, M, L, XL): ").upper()
    if talla not in ['S', 'M', 'L', 'XL']:
        print("Talla no válida.")
        return

    herramienta = input("¿Quieres generar la imagen con DALL·E (1) o NightCafe (2)? Ingresa 1 o 2: ")
    generar_imagen_completa(tipo_prenda, talla, herramienta)

ingresar_y_generar_patron()

# %% [markdown]
# **2. Genera moldes personalizados con medidas estandar ya normalizadas:**

# %%
# Función para calcular medidas básicas de una prenda
def calcular_medidas(tipo_prenda, talla):
    medidas = {
        'camisa': {
            'S': {'pecho': 90, 'cintura': 80, 'largo': 65, 'manga': 60},
            'M': {'pecho': 96, 'cintura': 86, 'largo': 68, 'manga': 62},
            'L': {'pecho': 102, 'cintura': 92, 'largo': 71, 'manga': 64},
            'XL': {'pecho': 108, 'cintura': 98, 'largo': 74, 'manga': 66},
        },
        'pantalon': {
            'S': {'cintura': 80, 'cadera': 95, 'largo': 100, 'pierna': 30},
            'M': {'cintura': 86, 'cadera': 100, 'largo': 102, 'pierna': 32},
            'L': {'cintura': 92, 'cadera': 105, 'largo': 104, 'pierna': 34},
            'XL': {'cintura': 98, 'cadera': 110, 'largo': 106, 'pierna': 36},
        },
        'vestido': {
            'S': {'pecho': 90, 'cintura': 80, 'largo': 85, 'cadera': 95},
            'M': {'pecho': 96, 'cintura': 86, 'largo': 88, 'cadera': 100},
            'L': {'pecho': 102, 'cintura': 92, 'largo': 91, 'cadera': 105},
            'XL': {'pecho': 108, 'cintura': 98, 'largo': 94, 'cadera': 110},
        }
    }

    return medidas[tipo_prenda].get(talla, "Talla no disponible")

# Función para generar una imagen con OpenAI (DALL·E)
def generar_imagen_openai(prompt, nombre_archivo="imagen_generada.png"):
    try:
        print(f"Generando imagen con el siguiente prompt:\n{prompt}")

        response = openai.Image.create(
            prompt=prompt,
            n=1,
            size="1024x1024"
        )

        # Verificar si la respuesta contiene datos
        if 'data' in response and len(response['data']) > 0:
            image_url = response['data'][0]['url']
            print("URL de la imagen generada:", image_url)

            # Descargar la imagen desde la URL generada
            response_img = requests.get(image_url)
            img = Image.open(BytesIO(response_img.content))

            # Mostrar la imagen
            img.show()

            # Guardar la imagen en Google Drive
            path_guardado = f"/content/drive/My Drive/{nombre_archivo}"
            img.save(path_guardado)
            print(f"Imagen guardada en {path_guardado}")

            return image_url, path_guardado  # Retornar la URL y la ruta guardada

        else:
            print("Error: No se recibió ninguna imagen en la respuesta.")
            return None, None

    except Exception as e:
        print("Ocurrió un error:", str(e))
        return None, None

# Función para generar la imagen completa de la prenda
def generar_imagen_completa(tipo_prenda, talla):
    prompt = f"Imagen completa de una {tipo_prenda}, talla {talla}. El diseño debe mostrar la prenda en su totalidad con detalles claros. Dibujo de alta calidad, monocromo, estilo vector."
    url_imagen, ruta_guardado = generar_imagen_openai(prompt, nombre_archivo=f"completa_{tipo_prenda}_{talla}.png")
    return url_imagen, ruta_guardado

# Función para generar las imágenes de cada pieza por separado
def generar_patrones_separados(tipo_prenda, talla, medidas):
    piezas = ['frente', 'espalda', 'manga', 'cuello'] if tipo_prenda == 'camisa' else \
             ['delantero', 'trasero', 'pierna'] if tipo_prenda == 'pantalon' else \
             ['cuerpo', 'mangas']

    urls_guardadas = []

    for pieza in piezas:
        prompt_pieza = f"Patrón de costura técnica para la {pieza} de una {tipo_prenda}, talla {talla}, con las siguientes medidas: {medidas}. " \
                       "El patrón debe estar bien centrado y ser similar a la imagen proporcionada, con medidas precisas claramente etiquetadas en cada pieza, con todas las marcas de costura necesarias. Dibujo técnico minimalista, de alta calidad, monocromo, estilo vector."

        url_imagen, ruta_guardado = generar_imagen_openai(prompt_pieza, nombre_archivo=f"patron_{pieza}_{tipo_prenda}_{talla}.png")
        if url_imagen and ruta_guardado:
            urls_guardadas.append((url_imagen, ruta_guardado))

    return urls_guardadas

# Función para ingresar datos y generar el patrón
def ingresar_y_generar_patron():
    print("Elige el tipo de prenda:")
    print("1. Camisa")
    print("2. Pantalón")
    print("3. Vestido")

    tipo_prenda = input("Ingresa el número del tipo de prenda (1, 2, 3): ")

    if tipo_prenda == '1':
        tipo_prenda = 'camisa'
    elif tipo_prenda == '2':
        tipo_prenda = 'pantalon'
    elif tipo_prenda == '3':
        tipo_prenda = 'vestido'
    else:
        print("Opción no válida.")
        return

    talla = input("Ingresa la talla (S, M, L, XL): ").upper()

    if talla not in ['S', 'M', 'L', 'XL']:
        print("Talla no válida.")
        return

    # Obtener medidas
    medidas = calcular_medidas(tipo_prenda, talla)

    if medidas == "Talla no disponible":
        print("Talla no disponible.")
        return

    # Generar imagen completa de la prenda
    url_completa, ruta_completa = generar_imagen_completa(tipo_prenda, talla)
    print(f"URL de la imagen completa: {url_completa}")
    print(f"Imagen completa guardada en: {ruta_completa}")

    # Generar imágenes de cada pieza por separado
    urls_guardadas = generar_patrones_separados(tipo_prenda, talla, medidas)

    # Mostrar y guardar las imágenes generadas
    for url, ruta in urls_guardadas:
        print(f"URL de la imagen generada: {url}")
        print(f"Imagen guardada en: {ruta}")

# 2. Propuesta de solución:
# Usa prompt engineering para generar instrucciones detalladas que permitan crear moldes personalizados en base a medidas, estilos, o tendencias específicas.
# Esto podría aplicarse tanto en texto (indicaciones paso a paso) como en imágenes (bocetos de moldes).

# Ejecutar la función principal para ingresar datos y generar el patrón
ingresar_y_generar_patron()

# %% [markdown]
# **3. Genera moldes personalizados con las medidas del usuario:**

# %%
# Función para calcular medidas básicas de una prenda
def calcular_medidas(tipo_prenda, talla):
    medidas = {
        'camisa': {
            'S': {'pecho': 90, 'cintura': 80, 'largo': 65, 'manga': 60},
            'M': {'pecho': 96, 'cintura': 86, 'largo': 68, 'manga': 62},
            'L': {'pecho': 102, 'cintura': 92, 'largo': 71, 'manga': 64},
            'XL': {'pecho': 108, 'cintura': 98, 'largo': 74, 'manga': 66},
        },
        'pantalon': {
            'S': {'cintura': 80, 'cadera': 95, 'largo': 100, 'pierna': 30},
            'M': {'cintura': 86, 'cadera': 100, 'largo': 102, 'pierna': 32},
            'L': {'cintura': 92, 'cadera': 105, 'largo': 104, 'pierna': 34},
            'XL': {'cintura': 98, 'cadera': 110, 'largo': 106, 'pierna': 36},
        },
        'vestido': {
            'S': {'pecho': 90, 'cintura': 80, 'largo': 85, 'cadera': 95},
            'M': {'pecho': 96, 'cintura': 86, 'largo': 88, 'cadera': 100},
            'L': {'pecho': 102, 'cintura': 92, 'largo': 91, 'cadera': 105},
            'XL': {'pecho': 108, 'cintura': 98, 'largo': 94, 'cadera': 110},
        }
    }

    return medidas[tipo_prenda].get(talla, "Talla no disponible")

# Función para pedir al usuario sus propias medidas
def ingresar_medidas_personalizadas(tipo_prenda):
    medidas_personalizadas = {}
    print(f"\nPor favor ingresa las siguientes medidas para la prenda '{tipo_prenda}'.")

    if tipo_prenda == 'camisa':
        medidas_personalizadas['pecho'] = float(input("Pecho (en cm): "))
        medidas_personalizadas['cintura'] = float(input("Cintura (en cm): "))
        medidas_personalizadas['largo'] = float(input("Largo (en cm): "))
        medidas_personalizadas['manga'] = float(input("Largo de la manga (en cm): "))

    elif tipo_prenda == 'pantalon':
        medidas_personalizadas['cintura'] = float(input("Cintura (en cm): "))
        medidas_personalizadas['cadera'] = float(input("Cadera (en cm): "))
        medidas_personalizadas['largo'] = float(input("Largo (en cm): "))
        medidas_personalizadas['pierna'] = float(input("Largo de la pierna (en cm): "))

    elif tipo_prenda == 'vestido':
        medidas_personalizadas['pecho'] = float(input("Pecho (en cm): "))
        medidas_personalizadas['cintura'] = float(input("Cintura (en cm): "))
        medidas_personalizadas['largo'] = float(input("Largo (en cm): "))
        medidas_personalizadas['cadera'] = float(input("Cadera (en cm): "))

    return medidas_personalizadas

# Función para generar una imagen con OpenAI (DALL·E)
def generar_imagen_openai(prompt, nombre_archivo="imagen_generada.png"):
    try:
        print(f"Generando imagen con el siguiente prompt:\n{prompt}")

        response = openai.Image.create(
            prompt=prompt,
            n=1,
            size="1024x1024"
        )

        # Verificar si la respuesta contiene datos
        if 'data' in response and len(response['data']) > 0:
            image_url = response['data'][0]['url']
            print("URL de la imagen generada:", image_url)

            # Descargar la imagen desde la URL generada
            response_img = requests.get(image_url)
            img = Image.open(BytesIO(response_img.content))

            # Mostrar la imagen
            img.show()

            # Guardar la imagen en Google Drive
            path_guardado = f"/content/drive/My Drive/{nombre_archivo}"
            img.save(path_guardado)
            print(f"Imagen guardada en {path_guardado}")

            return image_url, path_guardado  # Retornar la URL y la ruta guardada

        else:
            print("Error: No se recibió ninguna imagen en la respuesta.")
            return None, None

    except Exception as e:
        print("Ocurrió un error:", str(e))
        return None, None

# Función para generar la imagen completa de la prenda
def generar_imagen_completa(tipo_prenda, talla, medidas=None):
    prompt = f"Imagen completa de una {tipo_prenda}, talla {talla}. El diseño debe mostrar la prenda en su totalidad con detalles claros. Dibujo de alta calidad, monocromo, estilo vector."

    # Si se ingresaron medidas personalizadas, las agregamos al prompt
    if medidas:
        prompt += f" Con las siguientes medidas personalizadas: {medidas}."

    url_imagen, ruta_guardado = generar_imagen_openai(prompt, nombre_archivo=f"completa_{tipo_prenda}_{talla}.png")
    return url_imagen, ruta_guardado

# Función para generar las imágenes de cada pieza por separado
def generar_patrones_separados(tipo_prenda, talla, medidas):
    piezas = ['frente', 'espalda', 'manga', 'cuello'] if tipo_prenda == 'camisa' else \
             ['delantero', 'trasero', 'pierna'] if tipo_prenda == 'pantalon' else \
             ['cuerpo', 'mangas']

    urls_guardadas = []

    for pieza in piezas:
        prompt_pieza = f"Patrón de costura técnica para la {pieza} de una {tipo_prenda}, talla {talla}, con las siguientes medidas: {medidas}. " \
                       "El patrón debe estar bien centrado y ser similar a la imagen proporcionada, con medidas precisas claramente etiquetadas en cada pieza, con todas las marcas de costura necesarias. Dibujo técnico minimalista, de alta calidad, monocromo, estilo vector."

        url_imagen, ruta_guardado = generar_imagen_openai(prompt_pieza, nombre_archivo=f"patron_{pieza}_{tipo_prenda}_{talla}.png")
        if url_imagen and ruta_guardado:
            urls_guardadas.append((url_imagen, ruta_guardado))

    return urls_guardadas

# Función para ingresar datos y generar el patrón
def ingresar_y_generar_patron():
    print("Elige el tipo de prenda:")
    print("1. Camisa")
    print("2. Pantalón")
    print("3. Vestido")

    tipo_prenda = input("Ingresa el número del tipo de prenda (1, 2, 3): ")

    if tipo_prenda == '1':
        tipo_prenda = 'camisa'
    elif tipo_prenda == '2':
        tipo_prenda = 'pantalon'
    elif tipo_prenda == '3':
        tipo_prenda = 'vestido'
    else:
        print("Opción no válida.")
        return

    talla = input("Ingresa la talla (S, M, L, XL): ").upper()

    if talla not in ['S', 'M', 'L', 'XL']:
        print("Talla no válida.")
        return

    # Preguntar por medidas personalizadas
    personalizar = input("¿Quieres ingresar tus propias medidas? (si/no): ").lower()
    if personalizar == 'si':
        medidas = ingresar_medidas_personalizadas(tipo_prenda)
    else:
        medidas = calcular_medidas(tipo_prenda, talla)
        if medidas == "Talla no disponible":
            print("Talla no disponible.")
            return

    # Generar imagen completa de la prenda
    url_completa, ruta_completa = generar_imagen_completa(tipo_prenda, talla, medidas=medidas)
    print(f"URL de la imagen completa: {url_completa}")
    print(f"Imagen completa guardada en: {ruta_completa}")

    # Generar imágenes de cada pieza por separado
    urls_guardadas = generar_patrones_separados(tipo_prenda, talla, medidas)

    # Mostrar y guardar las imágenes generadas
    for url, ruta in urls_guardadas:
        print(f"URL de la imagen generada: {url}")
        print(f"Imagen guardada en: {ruta}")

# Ejecutar la función principal para ingresar datos y generar el patrón
ingresar_y_generar_patron()

# %% [markdown]
# **4. Genera un prompt para generar la imagen con NightCafe:**

# %%
def generar_prompt_alternativo(tipo_prenda, talla, plataforma="NightCafe"):
    prompt = f"Ilustración detallada de una {tipo_prenda}, talla {talla}. Diseño técnico con líneas limpias y proporciones realistas. Estilo vectorial monocromo, con detalles bien definidos y perspectiva plana."

    print("\n🔹 Usa este prompt para generar la imagen:")
    print(prompt)

    if plataforma.lower() == "nightcafe":
        print("\n🔹 Instrucciones para NightCafe:")
        print("1. Ve a https://creator.nightcafe.studio")
        print("2. Inicia sesión o regístrate para obtener créditos gratuitos.")
        print("3. Copia y pega el prompt en la sección de generación de imágenes.")
        print("4. Ajusta el estilo a 'vector' o 'boceto técnico' si está disponible.")
        print("5. Genera la imagen y descárgala.")

    elif plataforma.lower() == "leonardo.ai":
        print("\n🔹 Instrucciones para Leonardo.Ai:")
        print("1. Ve a https://leonardo.ai")
        print("2. Regístrate e inicia sesión.")
        print("3. Usa el generador de imágenes e ingresa el prompt.")
        print("4. Ajusta el modelo a algo adecuado para ilustraciones técnicas.")
        print("5. Descarga la imagen generada.")

    return prompt

# Prueba la función
tipo_prenda = "camisa"
talla = "M"
generar_prompt_alternativo(tipo_prenda, talla, plataforma="NightCafe")

# %% [markdown]
# **Guarda los cambios en Github:**

# %%
# Crear el directorio si no existe
os.makedirs("/content/tu_repositorio/", exist_ok=True)

# Guardar el cuaderno
import shutil
shutil.copy("/content/drive/My Drive/Trabajo_Final+Luida_Medina.ipynb", "/content/tu_repositorio/")

# Agregar, confirmar y subir cambios a GitHub
# !git add Trabajo_Final+Luida_Medina.ipynb
# !git commit -m "Agregando el cuaderno desde Google Colab"
# !git push origin main
